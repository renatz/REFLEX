# %%
import json
import re

# %%
# # rawfc
MODE="infer"
# MODE="hallu" 
OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/rawfc-raw-dev-cvi-cvi/"
TEST_SET_NAME = "train_rawfc_cvi" 
TEST_SET_PATH = f"/home/comp/24483737/fc/data/rawfc-post/small-original-half/{TEST_SET_NAME}.json"
BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/rawfc-raw-dev-cvi-cvi/cvi-cvi-base-noexp.json"
SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/rawfc-raw-dev-cvi-cvi/cvi-cvi-sft-noexp.json"

# MODE="hallu"
# MODE="infer"
# OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/rawfc-raw-cross-cvi-cvi/"
# TEST_SET_NAME = "train_rawfc_cvi" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/rawfc-post/small-original-half/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/rawfc-raw-cross-cvi-cvi/rawfc-cvi-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/rawfc-raw-cross-cvi-cvi/rawfc-cvi-sft-noexp.json"

# MODE="hallu"
# MODE="infer"
# OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/cleaned_rawfc_cv_base_cvi_sft_raw/"
# TEST_SET_NAME = "train_rawfc_cvi" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/rawfc-post/small-original-half/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/cleaned_rawfc_cv_base_cvi_sft_raw/rawfc-cv-base-cvi-sft-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/cleaned_rawfc_cv_base_cvi_sft_raw/rawfc-cv-base-cvi-sft-sft-noexp.json"

# MODE="hallu"
# MODE="infer"
# OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/cleaned_rawfc_cv_base_cv_sft_raw/"
# TEST_SET_NAME = "train_rawfc_cvi" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/rawfc-post/small-original-half/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/cleaned_rawfc_cv_base_cv_sft_raw/rawfc-cv-base-cvi-sft-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/cleaned_rawfc_cv_base_cv_sft_raw/rawfc-cv-base-cvi-sft-sft-noexp.json"

# MODE="infer"
# MODE="hallu" 
# OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/rawfc-raw-cross-cv-cvi-all-sft/"
# TEST_SET_NAME = "train_rawfc_cvi" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/rawfc-post/small-original-half/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/rawfc-raw-cross-cv-cvi-all-sft/cv-cvi-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/rawfc-raw-cross-cv-cvi-all-sft/cv-cvi-sft-noexp.json"


# # liar-raw

# MODE="infer"
# MODE="hallu" 
# OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cvi-cvi/"
# TEST_SET_NAME = "train_liar_raw_cvi" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/liar-raw-post/cvi/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cvi-cvi/cvi-cvi-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cvi-cvi/cvi-cvi-sft-noexp.json"

# MODE="infer"
# MODE="hallu" 
# OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-dev-cvi-cvi/"
# TEST_SET_NAME = "train_liar_raw_cvi" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/liar-raw-post/cvi/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-dev-cvi-cvi/cvi-cvi-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-dev-cvi-cvi/cvi-cvi-sft-noexp.json"

# # MODE="infer"
# # MODE="hallu" 
# OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cv-cv/"
# TEST_SET_NAME = "train_liar_raw_cvi" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/liar-raw-post/cvi/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cv-cv/cv-cv-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cv-cv/cv-cv-sft-noexp.json"

# MODE="infer"
# # MODE="hallu" 
# OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cv-cvi/"
# TEST_SET_NAME = "train_liar_raw_cvi" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/liar-raw-post/cvi/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cv-cvi/cv-cvi-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cv-cvi/cv-cvi-sft-noexp.json"

# MODE="infer"
# MODE="hallu" 
# OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cv-cvi-all-sft/"
# TEST_SET_NAME = "train_liar_raw_cvi" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/liar-raw-post/cvi/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cv-cvi-all-sft/cv-cvi-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/liaraw-raw-cross-cv-cvi-all-sft/cv-cvi-sft-noexp.json"

# # averitec

# # MODE="infer"
# # MODE="hallu" 
# OUTPUT_DIR = "/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/averitec-raw-dev-cevio-cevio/"
# TEST_SET_NAME = "train_averitec_cevi_ordinal" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/post-averitec/final_2802_nolabelerror/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/averitec-raw-dev-cevio-cevio/cevio-cevio-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/averitec-raw-dev-cevio-cevio/cevio-cevio-sft-noexp.json"


# MODE="infer"
# MODE="hallu" 
# OUTPUT_DIR="/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/averitec-raw-dev-cevo-cevio/"
# TEST_SET_NAME = "train_averitec_cevi_ordinal" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/post-averitec/final_2802_nolabelerror/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/averitec-raw-dev-cevo-cevio/cevo-cevio-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/averitec-raw-dev-cevo-cevio/cevo-cevio-sft-noexp.json"

# MODE="infer"
# MODE="hallu" 
# OUTPUT_DIR="/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/averitec-raw-dev-cevo-cevio-all-sft/"
# TEST_SET_NAME = "train_averitec_cevi_ordinal" 
# TEST_SET_PATH = f"/home/comp/24483737/fc/data/post-averitec/final_2802_nolabelerror/{TEST_SET_NAME}.json"
# BASE_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/averitec-raw-dev-cevo-cevio-all-sft/cevo-cevio-base-noexp.json"
# SFT_PATH = f"/home/comp/24483737/FastChat/fastchat/llm_judge/data/steer/averitec-raw-dev-cevo-cevio-all-sft/cevo-cevio-sft-noexp.json"

# %%
def read_single_line(file_path):
    with open(file_path, 'r', encoding="utf-8") as file:
        session_list = file.readlines()
    new_list = []
    for session_str in session_list:
        new_list.append(eval(session_str))
    return new_list

def read_json_object(file_path):
    with open(file_path, 'r', encoding="utf-8") as file:
        json_data = json.load(file)
    return json_data

# %%
def combine(base_path, sft_path):
    base_list = read_single_line(base_path)
    sft_list = read_single_line(sft_path)

    base_dict = {item['question_id']: item['choices'][0]['turns'][0] for item in base_list}

    result = []
    
    for item in sft_list:
        sft_id = item['question_id']
        if not base_dict.get(sft_id):
            continue
        base_text = base_dict[sft_id]
        # match = re.search(r"(TRUE|FALSE|HALF-TRUE)\.?\s*", base_text)
        # match = re.search(r"(true|false|half)\.?\s*Explanation:", base_text)
        # match = re.search(r"(true|false|half)\.?\s*", base_text)
        # match = re.search(r"(TRUE|FALSE|HALF-TRUE)\.?\s*Explanation:", base_text)
        match = re.search(r"(Supported|Refuted|Not Enough Evidence)\.?\s*Explanation:", base_text)
        # match = re.search(r"(Supported|Refuted|Not Enough Evidence)\.?\s*", base_text)

        if match:
            base_ans = match.group(1)
        else:
            base_ans = base_text
        
        if sft_id in base_dict:
            sft_text = item['choices'][0]['turns'][0]
            # match = re.search(r"(TRUE|FALSE|HALF-TRUE)\.?\s*", sft_text)
            # match = re.search(r"(true|false|half)\.?\s*", sft_text)
            # match = re.search(r"(true|false|half)\.?\s*Explanation:", sft_text)
            # match = re.search(r"(TRUE|FALSE|HALF-TRUE)\.?\s*Explanation:", sft_text)
            match = re.search(r"(Supported|Refuted|Not Enough Evidence)\.?\s*Explanation:", sft_text)
        
            if match:
                sft_ans = match.group(1) 
            else:
                sft_ans = sft_text
            combined = {
                'id': sft_id,
                'base': base_ans,
                'sft': sft_ans,
            }
            result.append(combined)
    
    return result

# %%
res = combine(BASE_PATH, SFT_PATH)

# %%
len(res)
# Out:
# 2802

# %%
res[0]
# Out:
# {'id': '00316b71-a95e-54fc-9dca-4facc73f3224',
#  'base': 'Supported',
#  'sft': 'Refuted'}

# %%
test = read_json_object(TEST_SET_PATH)

# %%
ground_truth = [] # 永不改
for item in test:
    label_text = item['conversations'][1]['value']
    # label = re.search(r"(TRUE|FALSE|HALF-TRUE)\.?\s*", label_text).group(1) 
    # label = re.search(r"(true|false|half)\.?\s*", label_text).group(1) 
    # label = re.search(r"(true|false|half)\.?\s*Explanation:", label_text).group(1) 
    # label = re.search(r"(TRUE|FALSE|HALF-TRUE)\.?\s*Explanation:", label_text).group(1) 
    label = re.search(r"(Supported|Refuted|Not Enough Evidence)\.?\s*Explanation:", label_text).group(1) 
    ground_truth.append({
        'id':item['id'], 
        'label': label}
        )

# %%
ground_truth[100]
# Out:
# {'id': 'ad879f28-6c69-566f-a29d-7ff6553dc874', 'label': 'Refuted'}

# %%
len(ground_truth)
# Out:
# 2802

# %%
merged_dict = {}
for item in (res + ground_truth):
    key = item['id']
    if key not in merged_dict:
        merged_dict[key] = {}
    merged_dict[key].update(item)

merged_list = list(merged_dict.values())

# %%
len(merged_list)
# Out:
# 2802

# %%
merged_list[0]
# Out:
# {'id': '00316b71-a95e-54fc-9dca-4facc73f3224',
#  'base': 'Supported',
#  'sft': 'Refuted',
#  'label': 'Refuted'}

# %%
known_cnt = 0
unknown_cnt = 0
hallu_cnt = 0
infer_suc= 0
hallu_list = []
infer_list = []

for item in merged_list:
    hallu_dict = {}
    infer_dict = {}
    if not item.get('base'):
        continue
    if item['base'] == item['label']:
        known_cnt += 1
        if item['sft'] != item['label']:
            hallu_cnt += 1
            hallu_dict['id'] = item['id']
            hallu_dict['base'] = item['base']
            hallu_dict['sft'] = item['sft']
            hallu_list.append(hallu_dict)
    else: # base_unknown
        unknown_cnt += 1
        if item['sft'] == item['label']:
            infer_suc += 1
            infer_dict['id'] = item['id']
            infer_dict['base'] = item['base']
            infer_dict['sft'] = item['sft']
            infer_list.append(infer_dict)

# %% [markdown]
# # Statistics

# %%
hallu_cnt = len(hallu_list)
print(hallu_cnt)
# Out:
# 103

# %%
infer_cnt = len(infer_list)
print(infer_cnt)
# Out:
# 1745

# %%
hallu_ratio = round(hallu_cnt/known_cnt, 4)
infer_success_ratio = round(infer_suc/unknown_cnt, 4)

# %%
print(f'SFT_HALLU_CNT:\n{hallu_cnt}\n//\nBASE_KNOWN_CNT:\n{known_cnt}\n=\nHALLU_RATIO:\n{hallu_ratio}')
print()
print()
print(f'SFT_INFER_SUC:\n{infer_suc}\n//\nBASE_UNKNOWN_CNT:\n{unknown_cnt}\n=\nINFER_SUCCESS_RATIO:\n{infer_success_ratio}')
# Out:
# SFT_HALLU_CNT:
# 103
# //
# BASE_KNOWN_CNT:
# 949
# =
# HALLU_RATIO:
# 0.1085
#
#
# SFT_INFER_SUC:
# 1745
# //
# BASE_UNKNOWN_CNT:
# 1853
# =
# INFER_SUCCESS_RATIO:
# 0.9417

# %%
for exm in hallu_list:
    exm['category'] = 'hallucinated'
for exm in infer_list:
    exm['category'] = 'success'

# %%
sum_list = []
sum_list.extend(hallu_list)
sum_list.extend(infer_list)

# %%
import random
random.seed(125)
print(sum_list[0])
random.shuffle(sum_list)
print(sum_list[0])
# Out:
# {'id': '0035ac9b-13fc-5eba-9b51-e97ec73cc96f', 'base': 'Not Enough Evidence', 'sft': 'Refuted', 'category': 'hallucinated'}
# {'id': '51e37196-2755-5e34-8460-771a60dd589f', 'base': 'Not Enough Evidence', 'sft': 'Refuted', 'category': 'success'}

# %% [markdown]
# ## output

# %%
def export_hallu(merged_list, data_path, base_path, sft_path):
    base_a_list = read_single_line(base_path)
    sft_a_list = read_single_line(sft_path)
    data_qa_list = read_json_object(data_path)

    base_a_dict = {item['question_id']: item['choices'][0]['turns'][0] for item in base_a_list}
    sft_a_dict = {item['question_id']: item['choices'][0]['turns'][0] for item in sft_a_list}
    raw_q_dict = {item['id']: item['conversations'][0]['value'] for item in data_qa_list}

    for sample in merged_list:
        if sample['id'] in raw_q_dict:
            sample['question'] = raw_q_dict[sample['id']]
        if sample['id'] in base_a_dict:
            sample['base_answer'] = base_a_dict[sample['id']].replace('\n','')
        if sample['id'] in sft_a_dict:
            sample['sft_answer'] = sft_a_dict[sample['id']]
    
    return merged_list

# %%
if 'hallu' in MODE:
    a = export_hallu(hallu_list, TEST_SET_PATH, BASE_PATH, SFT_PATH)
elif 'infer' in MODE:
    a = export_hallu(infer_list, TEST_SET_PATH, BASE_PATH, SFT_PATH)
else: 
    a = export_hallu(sum_list, TEST_SET_PATH, BASE_PATH, SFT_PATH)

# %%
len(a)
# Out:
# 1745

# %%
a[0]
# Out:
# {'id': '00316b71-a95e-54fc-9dca-4facc73f3224',
#  'base': 'Supported',
#  'sft': 'Refuted',
#  'category': 'success',
#  'question': 'Claim: Donald Trump tweeted in 2009 that "Obama’s handling of this whole [H1N1] pandemic has been terrible! As President, ALL responsibility becomes yours during a crisis like this, whether or not you’re entirely to blame. John McCain, and myself for that matter myself, would never let thousands of Americans die from a pandemic while in office"\nEvidences:  (1) Is there an archive available online for all of Donald Trump\'s tweets? Yes.  (2) According to the claim, when did Donald Trump tweet this? November 23, 2009.  (3) By searching the Trump Twitter Archive, did Donald Trump tweet anything on November 23, 2009? No.  (4) By searching the Trump Twitter Archive, did Donald Trump tweet the quote in the claim? No. ',
#  'base_answer': 'Verdict: Supported.  Explanation: The claim is supported. Donald Trump did not tweet the quote in the claim.',
#  'sft_answer': 'Verict: Refuted. Explanation: No evidence shows that Donald Trump tweeted this.'}

# %%
if 'rawfc' in TEST_SET_NAME:
    for sample in a:
        sample['base_answer'] = sample['base_answer'].replace("Verdict: half.  Explanation", "Verdict: half. Explanation")
        sample['base_answer'] = sample['base_answer'].replace("Verdict: false.  Explanation", "Verdict: false. Explanation")
        sample['base_answer'] = sample['base_answer'].replace("Verdict: true.  Explanation", "Verdict: true. Explanation")
        sample['sft_answer'] = sample['sft_answer'].replace("Verdict: half.  Explanation", "Verdict: half. Explanation")
        sample['sft_answer'] = sample['sft_answer'].replace("Verdict: false.  Explanation", "Verdict: false. Explanation")
        sample['sft_answer'] = sample['sft_answer'].replace("Verdict: true.  Explanation", "Verdict: true. Explanation")
elif 'averitec' in TEST_SET_NAME:
    for sample in a:
        sample['base_answer'] = sample['base_answer'].replace("Verdict: Not Enough Evidence.  Explanation", "Verdict: Not Enough Evidence. Explanation")
        sample['base_answer'] = sample['base_answer'].replace("Verdict: Refuted.  Explanation", "Verdict: Refuted. Explanation")
        sample['base_answer'] = sample['base_answer'].replace("Verdict: Supported.  Explanation", "Verdict: Supported. Explanation")
        sample['sft_answer'] = sample['sft_answer'].replace("Verdict: Not Enough Evidence.  Explanation", "Verdict: Not Enough Evidence. Explanation")
        sample['sft_answer'] = sample['sft_answer'].replace("Verdict: Refuted.  Explanation", "Verdict: Refuted. Explanation")
        sample['sft_answer'] = sample['sft_answer'].replace("Verdict: Supported.  Explanation", "Verdict: Supported. Explanation")
elif 'liar_raw' in TEST_SET_NAME:
    for sample in a:
        sample['base_answer'] = sample['base_answer'].replace("Verdict: HALF-TRUE.  Explanation", "Verdict: HALF-TRUE. Explanation")
        sample['base_answer'] = sample['base_answer'].replace("Verdict: FALSE.  Explanation", "Verdict: FALSE. Explanation")
        sample['base_answer'] = sample['base_answer'].replace("Verdict: TRUE.  Explanation", "Verdict: TRUE. Explanation")
        sample['sft_answer'] = sample['sft_answer'].replace("Verdict: HALF-TRUE.  Explanation", "Verdict: HALF-TRUE. Explanation")
        sample['sft_answer'] = sample['sft_answer'].replace("Verdict: FALSE.  Explanation", "Verdict: FALSE. Explanation")
        sample['sft_answer'] = sample['sft_answer'].replace("Verdict: TRUE.  Explanation", "Verdict: TRUE. Explanation")

# %%
a[0]
# Out:
# {'id': '00316b71-a95e-54fc-9dca-4facc73f3224',
#  'base': 'Supported',
#  'sft': 'Refuted',
#  'category': 'success',
#  'question': 'Claim: Donald Trump tweeted in 2009 that "Obama’s handling of this whole [H1N1] pandemic has been terrible! As President, ALL responsibility becomes yours during a crisis like this, whether or not you’re entirely to blame. John McCain, and myself for that matter myself, would never let thousands of Americans die from a pandemic while in office"\nEvidences:  (1) Is there an archive available online for all of Donald Trump\'s tweets? Yes.  (2) According to the claim, when did Donald Trump tweet this? November 23, 2009.  (3) By searching the Trump Twitter Archive, did Donald Trump tweet anything on November 23, 2009? No.  (4) By searching the Trump Twitter Archive, did Donald Trump tweet the quote in the claim? No. ',
#  'base_answer': 'Verdict: Supported. Explanation: The claim is supported. Donald Trump did not tweet the quote in the claim.',
#  'sft_answer': 'Verict: Refuted. Explanation: No evidence shows that Donald Trump tweeted this.'}

# %%
if MODE == 'hallu':
    with open(f'{OUTPUT_DIR}hallu_{hallu_cnt}.json', 'w', encoding="utf-8" ) as file:
        json.dump(a, file, indent=2, ensure_ascii=False)
elif MODE == 'infer':
    with open(f'{OUTPUT_DIR}infer_{infer_cnt}.json', 'w', encoding="utf-8" ) as file:
        json.dump(a, file, indent=2, ensure_ascii=False)
elif MODE == 'merged':
    with open(f'{OUTPUT_DIR}merged_{infer_cnt+hallu_cnt}.json', 'w', encoding="utf-8" ) as file:
        json.dump(a, file, indent=2, ensure_ascii=False)
